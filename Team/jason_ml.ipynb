# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import LinearSVC
from sklearn.metrics import accuracy_score
from sklearn import metrics
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('../datasets/health_numerical.csv')
df
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 319795 entries, 0 to 319794
# Data columns (total 18 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   HeartDisease      319795 non-null  int64
#  1   BMI               319795 non-null  float64
#  2   Smoking           319795 non-null  int64
#  3   AlcoholDrinking   319795 non-null  int64
#  4   Stroke            319795 non-null  int64
#  5   PhysicalHealth    319795 non-null  float64
#  6   MentalHealth      319795 non-null  float64
#  7   DiffWalking       319795 non-null  int64
#  8   Sex               319795 non-null  int64
#  9   AgeCategory       319795 non-null  int64
#  10  Race              319795 non-null  object
#  11  Diabetic          319795 non-null  int64
#  12  PhysicalActivity  319795 non-null  int64
#  13  GenHealth         319795 non-null  int64
#  14  SleepTime         319795 non-null  float64
#  15  Asthma            319795 non-null  int64
# ...

# %%
df1 = df[df['HeartDisease']==1]
df0 = df[df['HeartDisease']==0].sample(n=int(2*len(df1)))
df = pd.concat([df1,df0],axis=0)

# %%
X = df.drop(['HeartDisease', 'Race'], axis=1) #independent variables
y = df['HeartDisease'] #dependent variables
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=42) #what is random state?

# %%
model = RandomForestClassifier(n_estimators=300, max_depth=5)
model.fit(X_train, y_train) #create new code cells after this step
# Out:
# RandomForestClassifier(max_depth=5, n_estimators=300)

# %%
y_hat = model.predict(X_test)
accuracy_score(y_test, y_hat) #2:1
# Out:
# 0.7706405260594252

# %%
y_hat = model.predict(X_test)
accuracy_score(y_test, y_hat) #1.75:1
# Out:
# 0.7610096313517104

# %%
y_hat = model.predict(X_test)
accuracy_score(y_test, y_hat) #1.25:1
# Out:
# 0.7522325052768306

# %%
y_hat = model.predict(X_test)
accuracy_score(y_test, y_hat) #for 1.5:1 ratio of No HD to Yes HD
# Out:
# 0.7571418133995762

# %%
y_hat = model.predict(X_test)
accuracy_score(y_test, y_hat) #1:1 ratio
# Out:
# 0.7562557077625571

# %%
confusion_matrix = metrics.confusion_matrix(y_test, y_hat)
cm_display = metrics.ConfusionMatrixDisplay(confusion_matrix = confusion_matrix, display_labels = [False, True]) 
cm_display.plot()
plt.show() #1.5:1 ratio

# %%
from sklearn import metrics
import matplotlib.pyplot as plt

confusion_matrix = metrics.confusion_matrix(y_test, y_hat)
cm_display = metrics.ConfusionMatrixDisplay(confusion_matrix = confusion_matrix, display_labels = [False, True]) 
cm_display.plot()
plt.show() #1:1 ratio

# %%
from sklearn import metrics
import matplotlib.pyplot as plt

confusion_matrix = metrics.confusion_matrix(y_test, y_hat)
cm_display = metrics.ConfusionMatrixDisplay(confusion_matrix = confusion_matrix, display_labels = [False, True]) 
cm_display.plot()
plt.show() #1.25:1

# %%
confusion_matrix = metrics.confusion_matrix(y_test, y_hat)
cm_display = metrics.ConfusionMatrixDisplay(confusion_matrix = confusion_matrix, display_labels = [False, True]) 
cm_display.plot()
plt.show() #1.75:1

# %%
confusion_matrix = metrics.confusion_matrix(y_test, y_hat)
cm_display = metrics.ConfusionMatrixDisplay(confusion_matrix = confusion_matrix, display_labels = [False, True]) 
cm_display.plot()
plt.show() #2:1

# %% [markdown]
# Confusion matrices seem to converge around i=3

# %%
i=2.25
while i<10.25:
    df = pd.read_csv('../datasets/health_numerical.csv')
    df1 = df[df['HeartDisease']==1]
    df0 = df[df['HeartDisease']==0].sample(n=int(2*len(df1)))
    df = pd.concat([df1,df0],axis=0)
    X = df.drop(['HeartDisease', 'Race'], axis=1) #independent variables
    y = df['HeartDisease'] #dependent variables
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=42)
    model = RandomForestClassifier(n_estimators=300, max_depth=5)
    model.fit(X_train, y_train)
    y_hat = model.predict(X_test)
    print('accuracy for'+ str(i) + 'to 1 ratio' +str(accuracy_score(y_test, y_hat)))
    confusion_matrix = metrics.confusion_matrix(y_test, y_hat)
    cm_display = metrics.ConfusionMatrixDisplay(confusion_matrix = confusion_matrix, display_labels = [False, True]) 
    cm_display.plot()
    print('confusion for'+ str(i) + 'to 1 ratio')
    plt.show()
    i = i+0.25
# Out:
# accuracy for2.25to 1 ratio0.7653433999025816
# confusion for2.25to 1 ratio
# accuracy for2.5to 1 ratio0.770884072089625
# confusion for2.5to 1 ratio
# accuracy for2.75to 1 ratio0.7660740379931807
# confusion for2.75to 1 ratio
# accuracy for3.0to 1 ratio0.7695445689235265
# confusion for3.0to 1 ratio
# accuracy for3.25to 1 ratio0.7675962006819289
# confusion for3.25to 1 ratio
# accuracy for3.5to 1 ratio0.7680832927423283
# confusion for3.5to 1 ratio
# accuracy for3.75to 1 ratio0.7724062347783731
# confusion for3.75to 1 ratio
# accuracy for4.0to 1 ratio0.7685703848027278
# confusion for4.0to 1 ratio
# accuracy for4.25to 1 ratio0.7680224062347784
# confusion for4.25to 1 ratio
# accuracy for4.5to 1 ratio0.7682659522649781
# confusion for4.5to 1 ratio
# accuracy for4.75to 1 ratio0.7675962006819289
# confusion for4.75to 1 ratio
# accuracy for5.0to 1 ratio0.7707014125669751
# confusion for5.0to 1 ratio
# accuracy for5.25to 1 ratio0.7650998538723819
# confusion for5.25to 1 ratio
# ...
