# %% [markdown]
# # Welcome to your first EDA \(Exploratory Data Analysis\)

# %% [markdown]
# ### Our task at hand \-\- I hope you like penguins!
#
# For our mini project, we are going to use Pandas and Numpy to conduct a basic Exploratory Data Analysis on a penguins dataset. Specifically, we are looking at the <u>Palmer Archipelago \(Antarctica\) Penguins</u> dataset, which you can find here:  [https://raw.githubusercontent.com/mcnakhaee/palmerpenguins/master/palmerpenguins/data/penguins\-raw.csv](https://raw.githubusercontent.com/mcnakhaee/palmerpenguins/master/palmerpenguins/data/penguins-raw.csv)
#
# Not sure what an exploratory data analysis is? You can google it! The best definition I found is below:
#
# _**Exploratory Data Analysis**_ **refers to the critical process of performing initial investigations on data so as to discover patterns, to spot anomalies, to test hypotheses and to check assumptions with the help of summary statistics and graphical representations.**

# %%
#Before anything else let's import our library for data analysis, pandas.
import pandas as pd

# %% [markdown]
# ### Step 1: Loading in and understanding our data
#
# We need to read in our data. It is currently a .csv \(comma\-separated value\) file, and we generally use the pd.read\_csv\(\) function from pandas to read our data into a dataframe.

# %%
penguins_dataframe = pd.read_csv("https://raw.githubusercontent.com/mcnakhaee/palmerpenguins/master/palmerpenguins/data/penguins-raw.csv")

# %% [markdown]
# **TODO:** Can you run the .head\(\) and .tail\(\) function on our new dataframe? Can you print the name of all the columns in our dataframe? How about the number of rows?

# %%
# Run head() on penguins_dataframe
penguins_dataframe.head()
# Out:
#   studyName  Sample Number                              Species  Region  \
# 0   PAL0708              1  Adelie Penguin (Pygoscelis adeliae)  Anvers
# 1   PAL0708              2  Adelie Penguin (Pygoscelis adeliae)  Anvers
# 2   PAL0708              3  Adelie Penguin (Pygoscelis adeliae)  Anvers
# 3   PAL0708              4  Adelie Penguin (Pygoscelis adeliae)  Anvers
# 4   PAL0708              5  Adelie Penguin (Pygoscelis adeliae)  Anvers
#
#       Island               Stage Individual ID Clutch Completion    Date Egg  \
# 0  Torgersen  Adult, 1 Egg Stage          N1A1               Yes  2007-11-11
# 1  Torgersen  Adult, 1 Egg Stage          N1A2               Yes  2007-11-11
# 2  Torgersen  Adult, 1 Egg Stage          N2A1               Yes  2007-11-16
# 3  Torgersen  Adult, 1 Egg Stage          N2A2               Yes  2007-11-16
# 4  Torgersen  Adult, 1 Egg Stage          N3A1               Yes  2007-11-16
#
#    Culmen Length (mm)  Culmen Depth (mm)  Flipper Length (mm)  Body Mass (g)  \
# 0                39.1               18.7                181.0         3750.0
# 1                39.5               17.4                186.0         3800.0
# 2                40.3               18.0                195.0         3250.0
# 3                 NaN                NaN                  NaN            NaN
# 4                36.7               19.3                193.0         3450.0
#
#       Sex  Delta 15 N (o/oo)  Delta 13 C (o/oo)  \
# 0    MALE                NaN                NaN
# 1  FEMALE            8.94956          -24.69454
# 2  FEMALE            8.36821          -25.33302
# 3     NaN                NaN                NaN
# 4  FEMALE            8.76651          -25.32426
#
#                          Comments
# 0  Not enough blood for isotopes.
# 1                             NaN
# 2                             NaN
# 3              Adult not sampled.
# 4                             NaN

# %%
# Run tail() on penguins_dataframe
penguins_dataframe.tail()
# Out:
#     studyName  Sample Number                                    Species  \
# 339   PAL0910             64  Chinstrap penguin (Pygoscelis antarctica)
# 340   PAL0910             65  Chinstrap penguin (Pygoscelis antarctica)
# 341   PAL0910             66  Chinstrap penguin (Pygoscelis antarctica)
# 342   PAL0910             67  Chinstrap penguin (Pygoscelis antarctica)
# 343   PAL0910             68  Chinstrap penguin (Pygoscelis antarctica)
#
#      Region Island               Stage Individual ID Clutch Completion  \
# 339  Anvers  Dream  Adult, 1 Egg Stage         N98A2               Yes
# 340  Anvers  Dream  Adult, 1 Egg Stage         N99A1                No
# 341  Anvers  Dream  Adult, 1 Egg Stage         N99A2                No
# 342  Anvers  Dream  Adult, 1 Egg Stage        N100A1               Yes
# 343  Anvers  Dream  Adult, 1 Egg Stage        N100A2               Yes
#
#        Date Egg  Culmen Length (mm)  Culmen Depth (mm)  Flipper Length (mm)  \
# 339  2009-11-19                55.8               19.8                207.0
# 340  2009-11-21                43.5               18.1                202.0
# 341  2009-11-21                49.6               18.2                193.0
# 342  2009-11-21                50.8               19.0                210.0
# 343  2009-11-21                50.2               18.7                198.0
#
#      Body Mass (g)     Sex  Delta 15 N (o/oo)  Delta 13 C (o/oo)  \
# 339         4000.0    MALE            9.70465          -24.53494
# 340         3400.0  FEMALE            9.37608          -24.40753
# 341         3775.0    MALE            9.46180          -24.70615
# 342         4100.0    MALE            9.98044          -24.68741
# 343         3775.0  FEMALE            9.39305          -24.25255
#
#                                   Comments
# 339                                    NaN
# 340  Nest never observed with full clutch.
# 341  Nest never observed with full clutch.
# 342                                    NaN
# 343                                    NaN

# %%
# Print the name of all the columns in our dataframe
for columns in penguins_dataframe:
    print(columns)
# Out:
# studyName
# Sample Number
# Species
# Region
# Island
# Stage
# Individual ID
# Clutch Completion
# Date Egg
# Culmen Length (mm)
# Culmen Depth (mm)
# Flipper Length (mm)
# Body Mass (g)
# Sex
# Delta 15 N (o/oo)
# Delta 13 C (o/oo)
# Comments

# %%
# Use google to find out how to print the number of rows in this dataset.
print(penguins_dataframe.shape[0])
# Out:
# 344

# %% [markdown]
# ### Step 2: Do your research
#
# What do the column names mean? At this point you should look up the meanings of any columns you don't know about and make some comments below.
#
# Typically at this point we would read up on the domain we are performing data analysis on. To do research on penguins you should probably get to know something about penguins!

# %% [raw]
# What do these columns mean?
# study name - explains itself
# sample number - label a member of the species with a number
# species - species used
# region - geographfical region?
# island - island species is from?
# stage - stage in their lives
# individual id - their id
#
# ----------------------------------------
# (from the Internet)
#
# studyName
# Sampling expedition from which data were collected, generated, etc.
#
# Sample Number
# an integer denoting the continuous numbering sequence for each sample
#
# Species
# a character string denoting the penguin species
#
# Region
# a character string denoting the region of Palmer LTER sampling grid
#
# Island
# a character string denoting the island near Palmer Station where samples were collected
#
# Stage
# a character string denoting reproductive stage at sampling
#
# Individual ID
# a character string denoting the unique ID for each individual in dataset
#
# Clutch Completion
# a character string denoting if the study nest observed with a full clutch, i.e., 2 eggs
#
# Date Egg
# a date denoting the date study nest observed with 1 egg (sampled)
#
# Culmen Length
# a number denoting the length of the dorsal ridge of a bird's bill (millimeters)
#
# Culmen Depth
# a number denoting the depth of the dorsal ridge of a bird's bill (millimeters)
#
# Flipper Length
# an integer denoting the length penguin flipper (millimeters)
#
# Body Mass
# an integer denoting the penguin body mass (grams)
#
# Sex
# a character string denoting the sex of an animal
#
# Delta 15 N
# a number denoting the measure of the ratio of stable isotopes 15N:14N
#
# Delta 13 C
# a number denoting the measure of the ratio of stable isotopes 13C:12C
#
# Comments
# a character string with text providing additional relevant information for data

# %% [markdown]
# ### Step 3: Cleaning up our Data
#
# This data is a lot to take in. How do we know if we can even use this data? I see some weird columns and lots of N/A values.
#
# Let's talk through some functions to clean our data and see if it is salvageable. To start, we cannot use all of these columns. I'm thinking I want to get rid of "studyName" and "Comments" since they are not super useful for understanding the data relationships. I'll do that below.

# %%
#Make a list of what you want to drop
columns_to_drop = ['studyName', 'Comments']

#Drop the columns using drop()
penguins_dataframe.drop(columns_to_drop, axis=1, inplace = True) #axis = 1 lets pandas know we are dropping columns, not rows.

#Check that they are dropped
penguins_dataframe.head(1)
# Out:
#    Sample Number                              Species  Region     Island  \
# 0              1  Adelie Penguin (Pygoscelis adeliae)  Anvers  Torgersen
#
#                 Stage Individual ID Clutch Completion    Date Egg  \
# 0  Adult, 1 Egg Stage          N1A1               Yes  2007-11-11
#
#    Culmen Length (mm)  Culmen Depth (mm)  Flipper Length (mm)  Body Mass (g)  \
# 0                39.1               18.7                181.0         3750.0
#
#     Sex  Delta 15 N (o/oo)  Delta 13 C (o/oo)
# 0  MALE                NaN                NaN

# %% [markdown]
# **What does inplace mean?** This argument in the `drop()` function means we are changing the dataframe in place! If we had `inplace = False`, we would need to create a new dataframe like so:
#
# `new_penguins_dataframe = penguins_dataframe.drop(columns_to_drop, axis=1, inplace = False)`
#
# **TODO:** Can you drop the Sample Number, Individual ID, Delta 15 N \(o/oo\), and Delta 13 C \(o/oo\) columns using the example above?

# %%
# Drop the Sample Number, Individual ID, Delta 15 N (o/oo), and Delta 13 C (o/oo) columns using the example above.

columnsToDrop = ['Sample Number', 'Individual ID', 'Delta 15 N (o/oo)','Delta 13 C (o/oo)']
#Drop the columns using drop()
penguins_dataframe.drop(columnsToDrop, axis=1, inplace = True)

#Check that they are dropped
penguins_dataframe.head(1)
# Out:
#   studyName                              Species  Region     Island  \
# 0   PAL0708  Adelie Penguin (Pygoscelis adeliae)  Anvers  Torgersen
#
#                 Stage Clutch Completion    Date Egg  Culmen Length (mm)  \
# 0  Adult, 1 Egg Stage               Yes  2007-11-11                39.1
#
#    Culmen Depth (mm)  Flipper Length (mm)  Body Mass (g)   Sex  \
# 0               18.7                181.0         3750.0  MALE
#
#                          Comments
# 0  Not enough blood for isotopes.

# %% [markdown]
# #### Getting Rid of N/A's
#
# I see lots of N/A's, which we typically cannot visualize or use in machine learning.
# Now, I want to get rid of all the rows that have NA's in them. I'll show you how. **TODO:** Can you print the number of rows our dataframe has after I drop the NAs?

# %%
# This is a very convenient function to drop all rows that have N/A values!
penguins_dataframe.dropna(inplace=True)
penguins_dataframe.reset_index(drop=True, inplace=True) #Very good practice to reset how your rows are counted when you drop rows.

# %%
#Print the number of rows our new dataframe has.
print(penguins_dataframe.shape[0])
# Out:
# 43

# %% [markdown]
# ### Exploring the Data
#
# Pandas has some amazing tools for exploring your data. Since this is a **mini** project, we will walk through only a few key features of pandas exploration. You can expect to do lots of research on your own to best explore, clean, and visualize your data for your project.
#
# First we will learn how to access certain columns of data and use conditions to get subsets of data.

# %%
# access a column using df["<COLUMN_NAME"] or df.COLUMN_NAME
penguins_dataframe["Species"].head()
# Out:
# 0    Adelie Penguin (Pygoscelis adeliae)
# 1    Adelie Penguin (Pygoscelis adeliae)
# 2    Adelie Penguin (Pygoscelis adeliae)
# 3    Adelie Penguin (Pygoscelis adeliae)
# 4    Adelie Penguin (Pygoscelis adeliae)
# Name: Species, dtype: object

# %%
penguins_dataframe.Species.head()
# Out:
# 0    Adelie Penguin (Pygoscelis adeliae)
# 1    Adelie Penguin (Pygoscelis adeliae)
# 2    Adelie Penguin (Pygoscelis adeliae)
# 3    Adelie Penguin (Pygoscelis adeliae)
# 4    Adelie Penguin (Pygoscelis adeliae)
# Name: Species, dtype: object

# %%
#You can also access multiple columns using double brackets (printing a "list" of columns)
penguins_dataframe[["Species","Region"]].head()
# Out:
#                                Species  Region
# 0  Adelie Penguin (Pygoscelis adeliae)  Anvers
# 1  Adelie Penguin (Pygoscelis adeliae)  Anvers
# 2  Adelie Penguin (Pygoscelis adeliae)  Anvers
# 3  Adelie Penguin (Pygoscelis adeliae)  Anvers
# 4  Adelie Penguin (Pygoscelis adeliae)  Anvers

# %% [markdown]
# **TODO: Can you print the last five rows of the Island and Region columns?**

# %%
#Print the last five rows of the Island and Region columns.
print(penguins_dataframe[["Island","Region"]].tail())
# Out:
#    Island  Region
# 38  Dream  Anvers
# 39  Dream  Anvers
# 40  Dream  Anvers
# 41  Dream  Anvers
# 42  Dream  Anvers

# %% [markdown]
# <u>**Conditions in Pandas**</u>
#
# Pandas is also incredible for selecting subsets of columns that fit a certain condition. Check out the code below to get only the Adelie penguins.

# %%
penguins_dataframe[penguins_dataframe["Species"] == "Adelie Penguin (Pygoscelis adeliae)"].head()
# Out:
#                                Species  Region     Island               Stage  \
# 0  Adelie Penguin (Pygoscelis adeliae)  Anvers  Torgersen  Adult, 1 Egg Stage
# 1  Adelie Penguin (Pygoscelis adeliae)  Anvers  Torgersen  Adult, 1 Egg Stage
# 2  Adelie Penguin (Pygoscelis adeliae)  Anvers  Torgersen  Adult, 1 Egg Stage
# 3  Adelie Penguin (Pygoscelis adeliae)  Anvers  Torgersen  Adult, 1 Egg Stage
# 4  Adelie Penguin (Pygoscelis adeliae)  Anvers  Torgersen  Adult, 1 Egg Stage
#
#   Clutch Completion    Date Egg  Culmen Length (mm)  Culmen Depth (mm)  \
# 0               Yes  2007-11-11                39.1               18.7
# 1               Yes  2007-11-11                39.5               17.4
# 2               Yes  2007-11-16                40.3               18.0
# 3               Yes  2007-11-16                36.7               19.3
# 4               Yes  2007-11-16                39.3               20.6
#
#    Flipper Length (mm)  Body Mass (g)     Sex
# 0                181.0         3750.0    MALE
# 1                186.0         3800.0  FEMALE
# 2                195.0         3250.0  FEMALE
# 3                193.0         3450.0  FEMALE
# 4                190.0         3650.0    MALE

# %% [markdown]
# Conditions in pandas work just like `if` statements in python.
#
# **TODO: Can you tell me which species of penguin can have a flipper length greater than or equal to 230 by using conditions in pandas?**

# %%
# Use pandas to find out which species of penguin can have a flipper length greater than or equal to 230
print(penguins_dataframe[penguins_dataframe["Flipper Length (mm)"] >= 100].head())
# Out:
#   studyName                              Species  Region     Island  \
# 0   PAL0708  Adelie Penguin (Pygoscelis adeliae)  Anvers  Torgersen
# 1   PAL0708  Adelie Penguin (Pygoscelis adeliae)  Anvers  Torgersen
# 2   PAL0708  Adelie Penguin (Pygoscelis adeliae)  Anvers  Torgersen
# 3   PAL0708  Adelie Penguin (Pygoscelis adeliae)  Anvers  Torgersen
# 4   PAL0708  Adelie Penguin (Pygoscelis adeliae)  Anvers  Torgersen
#
#                 Stage Clutch Completion    Date Egg  Culmen Length (mm)  \
# 0  Adult, 1 Egg Stage               Yes  2007-11-11                39.1
# 1  Adult, 1 Egg Stage                No  2007-11-15                38.9
# 2  Adult, 1 Egg Stage                No  2007-11-15                39.2
# 3  Adult, 1 Egg Stage               Yes  2007-11-15                41.1
# 4  Adult, 1 Egg Stage               Yes  2007-11-15                38.6
#
#    Culmen Depth (mm)  Flipper Length (mm)  Body Mass (g)     Sex  \
# 0               18.7                181.0         3750.0    MALE
# 1               17.8                181.0         3625.0  FEMALE
# 2               19.6                195.0         4675.0    MALE
# 3               17.6                182.0         3200.0  FEMALE
# 4               21.2                191.0         3800.0    MALE
#
#                                 Comments
# 0         Not enough blood for isotopes.
# 1  Nest never observed with full clutch.
# 2  Nest never observed with full clutch.
# 3         Not enough blood for isotopes.
# 4         Not enough blood for isotopes.

# %% [markdown]
# **TODO:** Take 5 minutes to explore the dataset on your own. There's some space for you to code below.
#
# Think of what you want to learn. Maybe what the smallest flipper size penguin is? How about the smallest culmen width? What is the largest penguin by mass?

# %%
#sorting problems?
print(penguins_dataframe[penguins_dataframe["Flipper Length (mm)"] <= 175].head())
# Out:
#   studyName                              Species  Region  Island  \
# 6   PAL0708  Adelie Penguin (Pygoscelis adeliae)  Anvers  Biscoe
#
#                 Stage Clutch Completion    Date Egg  Culmen Length (mm)  \
# 6  Adult, 1 Egg Stage                No  2007-11-10                37.9
#
#    Culmen Depth (mm)  Flipper Length (mm)  Body Mass (g)     Sex  \
# 6               18.6                172.0         3150.0  FEMALE
#
#                                 Comments
# 6  Nest never observed with full clutch.

# %%
print(penguins_dataframe[penguins_dataframe["Culmen Depth (mm)"] <= 13.8].head())
# Out:
#    studyName                            Species  Region  Island  \
# 20   PAL0708  Gentoo penguin (Pygoscelis papua)  Anvers  Biscoe
# 23   PAL0809  Gentoo penguin (Pygoscelis papua)  Anvers  Biscoe
# 27   PAL0910  Gentoo penguin (Pygoscelis papua)  Anvers  Biscoe
#
#                  Stage Clutch Completion    Date Egg  Culmen Length (mm)  \
# 20  Adult, 1 Egg Stage                No  2007-11-27                40.9
# 23  Adult, 1 Egg Stage                No  2008-11-04                42.7
# 27  Adult, 1 Egg Stage                No  2009-12-01                47.2
#
#     Culmen Depth (mm)  Flipper Length (mm)  Body Mass (g)     Sex  \
# 20               13.7                214.0         4650.0  FEMALE
# 23               13.7                208.0         3950.0  FEMALE
# 27               13.7                214.0         4925.0  FEMALE
#
#                                  Comments
# 20  Nest never observed with full clutch.
# 23  Nest never observed with full clutch.
# 27  Nest never observed with full clutch.

# %%
print(penguins_dataframe[penguins_dataframe["Body Mass (g)"] >= 5700].head())
# Out:
#    studyName                            Species  Region  Island  \
# 24   PAL0809  Gentoo penguin (Pygoscelis papua)  Anvers  Biscoe
#
#                  Stage Clutch Completion    Date Egg  Culmen Length (mm)  \
# 24  Adult, 1 Egg Stage                No  2008-11-04                49.6
#
#     Culmen Depth (mm)  Flipper Length (mm)  Body Mass (g)   Sex  \
# 24               16.0                225.0         5700.0  MALE
#
#                                  Comments
# 24  Nest never observed with full clutch.

# %% [markdown]
# ### Visualize on the Fly with Pandas
#
# Before we create mind\-blowing visualizations, it is sometimes worth it to create quick visualizations to get ourselves oriented with the data and it's underlying patterns.
#
# I put a simple histogram below that helps me understand how the dataset is distributed. Notice that is is pretty hard to read and ugly, but it gets the job done for the data scientist. I now know that there are three species of penguin we are worried about, and that we have a lot more samples of the Adelie penguin than the Gentoo and Chinstrap \(a good to know for machine learning\).

# %%
# Create a histogram of a column's data using the df.hist() function. I found it here: https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.hist.html
penguins_dataframe.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f8d320caf40>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f8d3209a8e0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f8d32056f70>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f8d31ffda00>]],
#       dtype=object)

# %% [markdown]
# **TODO: Create a histogram of another column of your choice below.**

# %%
#Create a histogram of another column of your choice below.

# %% [markdown]
# **TODO:** Now, let's have some fun. Can you create plots using the following functions?
#
# 1. Scatter Plot: [https://pandas.pydata.org/pandas\-docs/version/0.25.0/reference/api/pandas.DataFrame.plot.scatter.html](https://pandas.pydata.org/pandas-docs/version/0.25.0/reference/api/pandas.DataFrame.plot.scatter.html)
# 2. Pie Plot: [https://pandas.pydata.org/docs/user\_guide/visualization.html\#visualization\-pie](https://pandas.pydata.org/docs/user_guide/visualization.html#visualization-pie)
#
# Pro challenge: Add a title to each!

# %%
#Create a scatter here
import matplotlib.pyplot as plt
penguins_dataframe.plot.scatter(x = 'Culmen Length (mm)', y = 'Flipper Length (mm)')
plt.title("Flipper length as a function of culmen depth")
# Out:
# Text(0.5, 1.0, 'title')

# %%
#Create a pie plot here - might look more like art than data science. Is a pie chart a good choice for the column?
#islands
penguins_dataframe.plot.pie(y = 'Body Mass (g)')

# %% [markdown]
# ### Creating Beautiful Visualizations with Plotly
#
# So far, it looks like a scatter plot might be our best bet! Now we want to make a beautiful scatter plot using `plotly.`Just like pandas and numpy, plotly is a module that lets us create beautiful visualizations in just a few lines of code.
#
# I'm only going to help with the import, so I need you to spend time on plotly's documentation in order to build the same scatter plot you did in the last section, but nicer. Maybe google "Scatter plots in plotly python" to start!

# %%
import plotly.express as px #importing plotly

# %% [markdown]
# **TODO:** Create a scatter plot using plotly. Please add a title here!
#
# Maybe google "Scatter plots in plotly python" to start!

# %%
# Create a scatter plot
fig = px.scatter(penguins_dataframe,x="Culmen Length (mm)", y="Flipper Length (mm)")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.9.0.min.js"></script>                <div id="dada0703-54fa-421c-a9f5-6009c7853188" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("dada0703-54fa-421c-a9f5-6009c7853188")) {                    Plotly.newPlot(                        "dada0703-54fa-421c-a9f5-6009c7853188",                        [{"hovertemplate":"Culmen Length (mm)=%{x}<br>Flipper Length (mm)=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"","orientation":"v","showlegend":false,"x":[39.1,38.9,39.2,41.1,38.6,36.6,37.9,40.5,37.6,39.8,40.8,41.1,35.9,41.8,36.2,37.7,38.5,43.1,37.0,39.7,40.9,49.0,47.3,42.7,49.6,45.5,50.5,47.2,46.5,50.0,50.3,58.0,43.2,50.6,46.7,52.0,50.5,49.5,46.9,53.5,51.9,43.5,49.6],"xaxis":"x","y":[181.0,181.0,195.0,182.0,191.0,185.0,172.0,180.0,181.0,184.0,195.0,182.0,190.0,198.0,187.0,198.0,190.0,197.0,185.0,193.0,214.0,216.0,222.0,208.0,225.0,210.0,225.0,214.0,192.0,196.0,197.0,181.0,187.0,193.0,195.0,197.0,200.0,200.0,192.0,205.0,206.0,202.0,193.0],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9 ...

# %% [markdown]
# **TODO:** Let's make it look even better. Copy your function from above but add another argument to the function by setting the `color="Species"`. Not sure what this means? Get to the scatter plots page on plotly and scroll down to the "Setting size and color with column names" section.

# %%
# Create the same scatter plot with color="Species". Feeling crazy? Set a column name to the "size" argument as well!
fig = px.scatter(penguins_dataframe,x="Culmen Length (mm)", y="Flipper Length (mm)", color = "Species", size = "Body Mass (g)")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.9.0.min.js"></script>                <div id="a91762f6-08e5-4774-9585-cb627b0eb984" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a91762f6-08e5-4774-9585-cb627b0eb984")) {                    Plotly.newPlot(                        "a91762f6-08e5-4774-9585-cb627b0eb984",                        [{"hovertemplate":"Species=Adelie Penguin (Pygoscelis adeliae)<br>Culmen Length (mm)=%{x}<br>Flipper Length (mm)=%{y}<br>Body Mass (g)=%{marker.size}<extra></extra>","legendgroup":"Adelie Penguin (Pygoscelis adeliae)","marker":{"color":"#636efa","size":[3750.0,3625.0,4675.0,3200.0,3800.0,3700.0,3150.0,3950.0,3300.0,4650.0,3900.0,3425.0,3050.0,4450.0,3150.0,3500.0,3325.0,3500.0,3400.0,4250.0],"sizemode":"area","sizeref":14.25,"symbol":"circle"},"mode":"markers","name":"Adelie Penguin (Pygoscelis adeliae)","orientation":"v","showlegend":true,"x":[39.1,38.9,39.2,41.1,38.6,36.6,37.9,40.5,37.6,39.8,40.8,41.1,35.9,41.8,36.2,37.7,38.5,43.1,37.0,39.7],"xaxis":"x","y":[181.0,181.0,195.0,182.0,191.0,185.0,172.0,180.0,181.0,184.0,195.0,182.0,190.0,198.0,187.0,198.0,190.0,197.0,185.0,193.0],"yaxis":"y","type":"scatter"},{"hovertemplate":"Species=Gentoo penguin (Pygoscelis papua)<br>Culmen Length (mm)=%{x}<br>Flipper Length (mm)=%{y}<br>Body Mass (g)=%{marker.size}<extra></extra>","legendgroup":"Gentoo penguin (Pygoscelis papua)","marker":{"color":"#EF553B","size":[4650.0,5550.0,5250.0,3950.0,5700.0,4200.0,5400.0,4925.0],"sizemode":"area","sizeref":14.25,"symbol":"circle"},"mode":"markers","name":"Gentoo penguin (Pygoscelis papua)","orientation":"v","showlegend":true,"x":[40.9,49.0,47.3,42.7,49.6,45.5,50.5,47.2],"xaxis":"x","y":[214.0,216.0,222.0,208.0,225.0,210.0,225.0,214.0],"yaxis":"y","type":"scatter"},{"hovertemplate":"Species=Chinstrap penguin (Pygoscelis antarctica)<br>Culmen Length (mm)=%{x}<br>Flipper Length (mm)=%{y}<br>Body Mass (g)=%{marker.size}<extra></extra>","legendgroup":"Chinstrap penguin (Pygoscelis antarctica)","marker":{"color":"#00cc96","size":[3500.0,3900.0,3300.0,3700.0,2900.0,3800.0,3300.0,4150.0,3400.0,3800.0,2700.0,4500.0,3950.0,3400.0,3775.0],"sizemode":"area","sizeref":14.25,"symbol":"circle"},"mode":"markers","name":"Chinstrap penguin (Pygoscelis antarctica)","orientation":"v","showlegend":true,"x":[46.5,50.0,50.3,58.0,43.2,50.6,46.7,52.0,50.5,49.5,46.9,53.5,51.9,43.5,49.6],"xaxis":"x","y":[192.0,196.0,197.0,181.0,187.0,193.0,195.0,197.0,200.0,200.0,192.0,205.0,206.0,202.0,193.0],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.11111111111111 ...

# %% [markdown]
# **Scatter Matrix:** I wanted to create a scatter plot for every possible numerical combination of 'Culmen Length \(mm\)', 'Culmen Depth \(mm\)', 'Flipper Length \(mm\)', and 'Body Mass \(g\)'. This could help me understand what is correlated and could mean a relationship between each other. The code to do so is below; are there any findings you can take away from this data?

# %%
# My scatter matrix!
numerical_penguins_df = penguins_dataframe[['Culmen Length (mm)', 'Culmen Depth (mm)', 'Flipper Length (mm)',
       'Body Mass (g)']]
fig = px.scatter_matrix(numerical_penguins_df)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.9.0.min.js"></script>                <div id="48bc2325-78d4-4b60-83f7-fb10d6c910aa" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("48bc2325-78d4-4b60-83f7-fb10d6c910aa")) {                    Plotly.newPlot(                        "48bc2325-78d4-4b60-83f7-fb10d6c910aa",                        [{"dimensions":[{"axis":{"matches":true},"label":"Culmen Length (mm)","values":[39.1,38.9,39.2,41.1,38.6,36.6,37.9,40.5,37.6,39.8,40.8,41.1,35.9,41.8,36.2,37.7,38.5,43.1,37.0,39.7,40.9,49.0,47.3,42.7,49.6,45.5,50.5,47.2,46.5,50.0,50.3,58.0,43.2,50.6,46.7,52.0,50.5,49.5,46.9,53.5,51.9,43.5,49.6]},{"axis":{"matches":true},"label":"Culmen Depth (mm)","values":[18.7,17.8,19.6,17.6,21.2,17.8,18.6,18.9,19.3,19.1,18.4,19.0,16.6,19.4,17.2,19.8,17.9,19.2,16.5,17.9,13.7,16.1,15.3,13.7,16.0,13.9,15.9,13.7,17.9,19.5,20.0,17.8,16.6,19.4,17.9,19.0,18.4,19.0,16.6,19.9,19.5,18.1,18.2]},{"axis":{"matches":true},"label":"Flipper Length (mm)","values":[181.0,181.0,195.0,182.0,191.0,185.0,172.0,180.0,181.0,184.0,195.0,182.0,190.0,198.0,187.0,198.0,190.0,197.0,185.0,193.0,214.0,216.0,222.0,208.0,225.0,210.0,225.0,214.0,192.0,196.0,197.0,181.0,187.0,193.0,195.0,197.0,200.0,200.0,192.0,205.0,206.0,202.0,193.0]},{"axis":{"matches":true},"label":"Body Mass (g)","values":[3750.0,3625.0,4675.0,3200.0,3800.0,3700.0,3150.0,3950.0,3300.0,4650.0,3900.0,3425.0,3050.0,4450.0,3150.0,3500.0,3325.0,3500.0,3400.0,4250.0,4650.0,5550.0,5250.0,3950.0,5700.0,4200.0,5400.0,4925.0,3500.0,3900.0,3300.0,3700.0,2900.0,3800.0,3300.0,4150.0,3400.0,3800.0,2700.0,4500.0,3950.0,3400.0,3775.0]}],"hovertemplate":"%{xaxis.title.text}=%{x}<br>%{yaxis.title.text}=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","symbol":"circle"},"name":"","showlegend":false,"type":"splom"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10, ...

# %% [markdown]
# ### Putting the DA in EDA
#
# We now have explored our data some, and have built some beautiful visualizations to showcase patterns our data. But having a plot doesn't mean anything to someone who can't understand how to read plots.
#
# Below you can continue your analysis if you have hypotheses you'd like to explore with the penguins \(i.e. is flipper length related to culmen depth? Which species has the largest culmen area?\). After you are done, please write up some descriptions for your findings on this dataset. One question we answered earlier was _which species has the largest flipper length?_ You can start with you

# %%
#Continue your analysis below -- try something new!

# %%
#Continue your analysis

# %% [raw]
# Write up some descriptions for your findings here....

# %% [markdown]
# Thank you!
